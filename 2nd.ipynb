# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.2.2 is available.
# You should consider upgrading via the 'c:\users\vishal kumawat\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import pandas as pd

# %%
l1=['vishal','kumawat']

# %%
a=pd.Series(l1)

# %%
a.shape
# Out:
# (2,)

# %%
a
# output='none'
# Out:
# 0     vishal
# 1    kumawat
# dtype: object

# %%
a.values
# Out:
# array(['vishal', 'kumawat'], dtype=object)

# %%
a.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %% [raw]
# a.dtype

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# a.product()

# %%
a.sum()
# Out:
# 'vishalkumawat'

# %%
a=pd.Series([1,2,3,4,5])

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a.sum()
# Out:
# 15

# %%
a.product()
# Out:
# 120

# %%
a.mean()
# Out:
# 3.0

# %%
a.median()
# Out:
# 3.0

# %%
a.sort_values(ascending=False)
# Out:
# 4    5
# 3    4
# 2    3
# 1    2
# 0    1
# dtype: int64

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
li={
    1:"apple",
    2:"banana",
    3:"cat"
    
}

# %%
li
# Out:
# {1: 'apple', 2: 'banana', 3: 'cat'}

# %%
li=pd.Series(li)

# %%
li
# Out:
# 1     apple
# 2    banana
# 3       cat
# dtype: object

# %%
l1=[1,2,3,4,5]
l2=['a','b','c','d','e']

# %%
li=pd.Series(index=l1,data=l2)

# %%
li
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# 5    e
# dtype: object

# %%
a=pd.DataFrame([[1,2,3],[1,2,3],[1,2,3]])

# %%
a
# Out:
#    0  1  2
# 0  1  2  3
# 1  1  2  3
# 2  1  2  3

# %%
data=pd.read_csv('jamesbond.csv')

# %%
data.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
data.tail(20)
# Out:
#                                Film  Year           Actor            Director  \
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# ...

# %%
# data.head(60)

# %%
len(data)
# Out:
# 26

# %%
data[:1]
# Out:
#      Film  Year         Actor       Director  Box Office  Budget  \
# 0  Dr. No  1962  Sean Connery  Terence Young       448.8     7.0
#
#    Bond Actor Salary
# 0                0.6

# %%
data[1:5]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
sorted(data,reverse=True)
# Out:
# ['Year',
#  'Film',
#  'Director',
#  'Budget',
#  'Box Office',
#  'Bond Actor Salary',
#  'Actor']

# %%
a=list(data)

# %%
a
# Out:
# ['Film',
#  'Year',
#  'Actor',
#  'Director',
#  'Box Office',
#  'Budget',
#  'Bond Actor Salary']

# %%
data
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
data.Film="hjhhh"

# %%
data
# Out:
#      Film  Year           Actor            Director  Box Office  Budget  \
# 0   hjhhh  1962    Sean Connery       Terence Young       448.8     7.0
# 1   hjhhh  1963    Sean Connery       Terence Young       543.8    12.6
# 2   hjhhh  1964    Sean Connery        Guy Hamilton       820.4    18.6
# 3   hjhhh  1965    Sean Connery       Terence Young       848.1    41.9
# 4   hjhhh  1967     David Niven          Ken Hughes       315.0    85.0
# 5   hjhhh  1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 6   hjhhh  1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 7   hjhhh  1971    Sean Connery        Guy Hamilton       442.5    34.7
# 8   hjhhh  1973     Roger Moore        Guy Hamilton       460.3    30.8
# 9   hjhhh  1974     Roger Moore        Guy Hamilton       334.0    27.7
# 10  hjhhh  1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 11  hjhhh  1979     Roger Moore       Lewis Gilbert       535.0    91.5
# ...

# %%
data=pd.read_csv('jamesbond.csv',index_col='Film')

# %%
data
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
data.value_counts()
# Out:
# Year  Actor           Director            Box Office  Budget  Bond Actor Salary
# 1962  Sean Connery    Terence Young       448.8       7.0     0.6                  1
# 1963  Sean Connery    Terence Young       543.8       12.6    1.6                  1
# 2008  Daniel Craig    Marc Forster        514.2       181.4   8.1                  1
# 2006  Daniel Craig    Martin Campbell     581.5       145.3   3.3                  1
# 2002  Pierce Brosnan  Lee Tamahori        465.4       154.2   17.9                 1
# 1999  Pierce Brosnan  Michael Apted       439.5       158.3   13.5                 1
# 1997  Pierce Brosnan  Roger Spottiswoode  463.2       133.9   10.0                 1
# 1995  Pierce Brosnan  Martin Campbell     518.5       76.9    5.1                  1
# 1989  Timothy Dalton  John Glen           250.9       56.7    7.9                  1
# 1987  Timothy Dalton  John Glen           313.5       68.8    5.2                  1
# ...

# %%
data[data['Year']>1980]
# Out:
#                          Year           Actor            Director  Box Office  \
# Film
# For Your Eyes Only       1981     Roger Moore           John Glen       449.4
# Never Say Never Again    1983    Sean Connery      Irvin Kershner       380.0
# Octopussy                1983     Roger Moore           John Glen       373.8
# A View to a Kill         1985     Roger Moore           John Glen       275.2
# The Living Daylights     1987  Timothy Dalton           John Glen       313.5
# Licence to Kill          1989  Timothy Dalton           John Glen       250.9
# GoldenEye                1995  Pierce Brosnan     Martin Campbell       518.5
# Tomorrow Never Dies      1997  Pierce Brosnan  Roger Spottiswoode       463.2
# The World Is Not Enough  1999  Pierce Brosnan       Michael Apted       439.5
# Die Another Day          2002  Pierce Brosnan        Lee Tamahori       465.4
# Casino Royale            2006    Daniel Craig     Martin Campbell       581.5
# ...
